# %% [markdown]
# # Loading initial packages:

# %%
## helpful packages

# Administrative stuff:
import os

# For Data manipulation:
import pandas as pd
import numpy as np
import random
import re

# Nice to haves
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon
# import googlemaps
import plotly.graph_objects as go

## dynamic text updating
from IPython.display import Markdown as md

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Initial Data Load - 2019 Data for Air and Health

# %%
air_data = pd.read_csv("annual_aqi_by_county_2019.csv",low_memory=False)
air_data.shape
air_data.head()
# Out:
# (1020, 18)
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2019            271        237             34
# 1  Alabama     Clay  2019            107         97             10
# 2  Alabama  Colbert  2019            263        252             11
# 3  Alabama   DeKalb  2019            361        324             37
# 4  Alabama   Elmore  2019            228        208             20
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0       80                   52          37        0
# 1               0       67                   50          30        0
# 2               0       61                   47          37        0
# 3               0       90                   51          39        0
# 4               0      100                   50          39        0
#
#    Days NO2  Days Ozone  Days PM2.5  Days PM10
# 0         0         220          51          0
# 1         0           0         107          0
# 2         0         228          35          0
# 3         0         331          30          0
# 4         0         228           0          0

# %%
# Loading initial data:
health_data = pd.read_csv("PLACES__Local_Data_for_Better_Health__Census_Tract_Data_2021_release.csv",
                          low_memory=False)
health_data.shape
health_data.head()
# Out:
# (2125561, 23)
#    Year StateAbbr  StateDesc  CountyName  CountyFIPS  LocationName DataSource  \
# 0  2018        AL    Alabama     Baldwin        1003    1003011601      BRFSS
# 1  2019        ME      Maine       Waldo       23027   23027045000      BRFSS
# 2  2019        AL    Alabama     Calhoun        1015    1015002300      BRFSS
# 3  2019        LA  Louisiana  Tangipahoa       22105   22105953500      BRFSS
# 4  2019        ME      Maine  Cumberland       23005   23005014000      BRFSS
#
#                 Category                                            Measure  \
# 0             Prevention  Cervical cancer screening among adult women ag...
# 1          Health Status  Fair or poor self-rated health status among ad...
# 2        Health Outcomes               Obesity among adults aged >=18 years
# 3  Health Risk Behaviors       Current smoking among adults aged >=18 years
# 4  Health Risk Behaviors       Current smoking among adults aged >=18 years
#
#   Data_Value_Unit  ... Data_Value_Footnote  Low_Confidence_Limit  \
# 0               %  ...                 NaN                  83.5
# 1               %  ...                 NaN                  17.4
# 2               %  ...                 NaN                  38.0
# 3               %  ...                 NaN                  22.3
# 4               %  ...                 NaN                  14.7
#
#    High_Confidence_Limit  TotalPopulation                       Geolocation  \
# 0                   87.1             6062  POINT (-87.55879555 30.41466842)
# 1                   20.3             5969  POINT (-69.23270168 44.42005508)
# 2                   40.0             3843  POINT (-85.67101785 33.93457433)
# 3                   25.4             7225  POINT (-90.36823496 30.77718215)
# 4                   20.3             3872  POINT (-70.61427542 43.97054122)
#
#     LocationID  CategoryID MeasureId  DataValueTypeID  \
# 0   1003011601     PREVENT  CERVICAL           CrdPrv
# 1  23027045000    HLTHSTAT     GHLTH           CrdPrv
# 2   1015002300     HLTHOUT   OBESITY           CrdPrv
# 3  22105953500     RISKBEH  CSMOKING           CrdPrv
# 4  23005014000     RISKBEH  CSMOKING           CrdPrv
#
#          Short_Question_Text
# 0  Cervical Cancer Screening
# 1             General Health
# 2                    Obesity
# 3            Current Smoking
# 4            Current Smoking
#
# [5 rows x 23 columns]

# %% [markdown]
# # Fitler for Kentucky and 2019

# %%
health_ken = health_data[health_data["StateDesc"] == "Kentucky"].reset_index()

health_ken_2019 = health_ken[health_ken["Year"]==2019].copy()
print("Length of original health data: " + str(len(health_data.index)))
print("Length of Kentucky 2019 health data: " + str(len(health_ken_2019.index)))
health_ken.head()
health_ken.shape
# Out:
# Length of original health data: 2125561
# Length of Kentucky 2019 health data: 24332
#    index  Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName  \
# 0   3596  2019        KY  Kentucky      Adair       21001   21001970300
# 1   3597  2019        KY  Kentucky      Adair       21001   21001970402
# 2   3598  2019        KY  Kentucky   Anderson       21005   21005950201
# 3   3599  2019        KY  Kentucky       Bell       21013   21013960200
# 4   3600  2019        KY  Kentucky       Bell       21013   21013960300
#
#   DataSource               Category  \
# 0      BRFSS  Health Risk Behaviors
# 1      BRFSS        Health Outcomes
# 2      BRFSS        Health Outcomes
# 3      BRFSS        Health Outcomes
# 4      BRFSS        Health Outcomes
#
#                                              Measure  ... Data_Value_Footnote  \
# 0  No leisure-time physical activity among adults...  ...                 NaN
# 1                Stroke among adults aged >=18 years  ...                 NaN
# 2            Depression among adults aged >=18 years  ...                 NaN
# 3                Stroke among adults aged >=18 years  ...                 NaN
# 4                Stroke among adults aged >=18 years  ...                 NaN
#
#   Low_Confidence_Limit  High_Confidence_Limit  TotalPopulation  \
# 0                 41.5                   48.3             3016
# 1                  3.0                    3.6             4261
# 2                 25.5                   27.9             5372
# 3                  5.4                    6.4             5150
# 4                  5.0                    6.2             2381
#
#                         Geolocation   LocationID  CategoryID   MeasureId  \
# 0  POINT (-85.15821669 37.13121962)  21001970300     RISKBEH         LPA
# 1  POINT (-85.26802881 37.12055109)  21001970402     HLTHOUT      STROKE
# 2  POINT (-84.92306901 38.02049683)  21005950201     HLTHOUT  DEPRESSION
# 3  POINT (-83.73909778 36.76433928)  21013960200     HLTHOUT      STROKE
# 4  POINT (-83.61861461 36.71356868)  21013960300     HLTHOUT      STROKE
#
#   DataValueTypeID  Short_Question_Text
# 0          CrdPrv  Physical Inactivity
# 1          CrdPrv               Stroke
# 2          CrdPrv           Depression
# 3          CrdPrv               Stroke
# 4          CrdPrv               Stroke
#
# [5 rows x 24 columns]
# (33170, 24)

# %%
#filter out air data of kentucky 
air_ken = air_data[air_data["State"] == "Kentucky"].reset_index()

air_ken_2019 = air_ken[air_ken["Year"]==2019].copy()

#print the index of air data of kentucky
print("Length of original air data: " + str(len(air_data.index)))
print("Length of Kentucky 2019 air data: " + str(len(air_ken_2019.index)))

air_ken.head()
# Out:
# Length of original air data: 1020
# Length of Kentucky 2019 air data: 27
#    index     State    County  Year  Days with AQI  Good Days  Moderate Days  \
# 0    326  Kentucky      Bell  2019            263        243             20
# 1    327  Kentucky     Boone  2019            239        222             17
# 2    328  Kentucky      Boyd  2019            365        313             52
# 3    329  Kentucky   Bullitt  2019            243        214             29
# 4    330  Kentucky  Campbell  2019            362        298             63
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    1               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0       77                   49          39        0
# 1               0       80                   49          39        0
# 2               0       74                   53          39        0
# 3               0       93                   51          41        0
# 4               0      108                   56          40        0
#
#    Days NO2  Days Ozone  Days PM2.5  Days PM10
# 0         0         234          29          0
# 1         0         239           0          0
# 2        11         192         160          2
# 3         0         243           0          0
# 4        21         189         152          0

# %% [markdown]
# # Number of County in both the dataset

# %%
#checking number of County's is both the datasets

print("Number of unique counties in health data: " + str(health_ken_2019['CountyName'].nunique()))

print("Number of unique counties in air data: " + str(air_ken_2019['County'].nunique()))


pd.DataFrame(health_ken_2019['CountyName'].value_counts())


pd.DataFrame(air_ken_2019['County'].value_counts())
# Out:
# Number of unique counties in health data: 120
# Number of unique counties in air data: 27
#            CountyName
# Jefferson        4180
# Fayette          1804
# Kenton            902
# Campbell          550
# Warren            528
# ...               ...
# Gallatin           44
# Powell             44
# Trimble            44
# Hickman            22
# Robertson          22
#
# [120 rows x 1 columns]
#             County
# Bell             1
# Jefferson        1
# Warren           1
# Trigg            1
# Simpson          1
# Pulaski          1
# Pike             1
# Perry            1
# Oldham           1
# Morgan           1
# McCracken        1
# Livingston       1
# Jessamine        1
# Henderson        1
# Boone            1
# Hardin           1
# Hancock          1
# Greenup          1
# Fayette          1
# Edmonson         1
# Daviess          1
# Christian        1
# Carter           1
# Campbell         1
# Bullitt          1
# Boyd             1
# Washington       1

# %% [markdown]
# # Number of Health-related Categories in Health Data

# %%
#health_ken['Category'].nunique()

print("Number of unique category in health data: " + str(health_ken_2019['Category'].nunique()))

pd.DataFrame(health_ken_2019['Category'].value_counts())
# Out:
# Number of unique category in health data: 4
#                        Category
# Health Outcomes           13272
# Prevention                 4424
# Health Risk Behaviors      3318
# Health Status              3318

# %% [markdown]
# # Number of Measure in Health Data

# %%
#health_ken['Measure'].nunique()

print("Number of unique Measure in health data: " + str(health_ken_2019['Measure'].nunique()))


pd.DataFrame(health_ken_2019['Measure'].value_counts())
# Out:
# Number of unique Measure in health data: 22
#                                                     Measure
# No leisure-time physical activity among adults ...     1106
# Stroke among adults aged >=18 years                    1106
# Chronic obstructive pulmonary disease among adu...     1106
# Chronic kidney disease among adults aged >=18 y...     1106
# Diagnosed diabetes among adults aged >=18 years        1106
# Visits to doctor for routine checkup within the...     1106
# Current smoking among adults aged >=18 years           1106
# Current lack of health insurance among adults a...     1106
# Binge drinking among adults aged >=18 years            1106
# High blood pressure among adults aged >=18 years       1106
# Cancer (excluding skin cancer) among adults age...     1106
# Mental health not good for >=14 days among adul...     1106
# Obesity among adults aged >=18 years                   1106
# Coronary heart disease among adults aged >=18 y...     1106
# Physical health not good for >=14 days among ad...     1106
# High cholesterol among adults aged >=18 years w...     1106
# Current asthma among adults aged >=18 years            1106
# Taking medicine for high blood pressure control...     1106
# Cholesterol screening among adults aged >=18 years     1106
# Arthritis among adults aged >=18 years                 1106
# Depression among adults aged >=18 years                1106
# Fair or poor self-rated health status among adu...     1106

# %% [markdown]
# # Number of category id

# %%
#print the number of category id

print("Number of unique Category Id in health data: " + str(health_ken_2019['CategoryID'].nunique()))

pd.DataFrame(health_ken_2019['CategoryID'].value_counts())
# Out:
# Number of unique Category Id in health data: 4
#           CategoryID
# HLTHOUT        13272
# PREVENT         4424
# RISKBEH         3318
# HLTHSTAT        3318

# %% [markdown]
# # Number of measure id

# %%
#print the number of measure id

print("Number of unique Measure Id in health data: " + str(health_ken_2019['MeasureId'].nunique()))

pd.DataFrame(health_ken_2019['MeasureId'].value_counts())
# Out:
# Number of unique Measure Id in health data: 22
#             MeasureId
# LPA              1106
# STROKE           1106
# COPD             1106
# KIDNEY           1106
# DIABETES         1106
# CHECKUP          1106
# CSMOKING         1106
# ACCESS2          1106
# BINGE            1106
# BPHIGH           1106
# CANCER           1106
# MHLTH            1106
# OBESITY          1106
# CHD              1106
# PHLTH            1106
# HIGHCHOL         1106
# CASTHMA          1106
# BPMED            1106
# CHOLSCREEN       1106
# ARTHRITIS        1106
# DEPRESSION       1106
# GHLTH            1106

# %%
#aggregate category and mesure 
agg=pd.DataFrame(health_ken_2019.groupby(["Category", "Measure"]).agg('count')["CategoryID"])
agg
# Out:
#                                                                           CategoryID
# Category              Measure
# Health Outcomes       Arthritis among adults aged >=18 years                    1106
#                       Cancer (excluding skin cancer) among adults age...        1106
#                       Chronic kidney disease among adults aged >=18 y...        1106
#                       Chronic obstructive pulmonary disease among adu...        1106
#                       Coronary heart disease among adults aged >=18 y...        1106
#                       Current asthma among adults aged >=18 years               1106
#                       Depression among adults aged >=18 years                   1106
#                       Diagnosed diabetes among adults aged >=18 years           1106
#                       High blood pressure among adults aged >=18 years          1106
#                       High cholesterol among adults aged >=18 years w...        1106
#                       Obesity among adults aged >=18 years                      1106
#                       Stroke among adults aged >=18 years                       1106
# Health Risk Behaviors Binge drinking among adults aged >=18 years               1106
#                       Current smoking among adults aged >=18 years              1106
#                       No leisure-time physical activity among adults ...        1106
# Health Status         Fair or poor self-rated health status among adu...        1106
#                       Mental health not good for >=14 days among adul...        1106
#                       Physical health not good for >=14 days among ad...        1106
# Prevention            Cholesterol screening among adults aged >=18 years        1106
#                       Current lack of health insurance among adults a...        1106
#                       Taking medicine for high blood pressure control...        1106
#                       Visits to doctor for routine checkup within the...        1106

# %% [markdown]
# ## Cleaning Health Data:

# %%
## drop columns that we are not gonna use
health_ken_2019_clean = health_ken_2019.drop(['StateAbbr',"LocationName", 'DataSource','StateDesc', 'CategoryID',
                                          'Data_Value_Footnote', "Data_Value_Footnote_Symbol",'DataValueTypeID', 
                                          "Short_Question_Text", "Low_Confidence_Limit", "High_Confidence_Limit"],
                                         axis=1)
health_ken_2019_clean.shape
health_ken_2019_clean.head()
# Out:
# (24332, 13)
#    index  Year CountyName  CountyFIPS               Category  \
# 0   3596  2019      Adair       21001  Health Risk Behaviors
# 1   3597  2019      Adair       21001        Health Outcomes
# 2   3598  2019   Anderson       21005        Health Outcomes
# 3   3599  2019       Bell       21013        Health Outcomes
# 4   3600  2019       Bell       21013        Health Outcomes
#
#                                              Measure Data_Value_Unit  \
# 0  No leisure-time physical activity among adults...               %
# 1                Stroke among adults aged >=18 years               %
# 2            Depression among adults aged >=18 years               %
# 3                Stroke among adults aged >=18 years               %
# 4                Stroke among adults aged >=18 years               %
#
#     Data_Value_Type  Data_Value  TotalPopulation  \
# 0  Crude prevalence        44.8             3016
# 1  Crude prevalence         3.3             4261
# 2  Crude prevalence        26.6             5372
# 3  Crude prevalence         5.8             5150
# 4  Crude prevalence         5.5             2381
#
#                         Geolocation   LocationID   MeasureId
# 0  POINT (-85.15821669 37.13121962)  21001970300         LPA
# 1  POINT (-85.26802881 37.12055109)  21001970402      STROKE
# 2  POINT (-84.92306901 38.02049683)  21005950201  DEPRESSION
# 3  POINT (-83.73909778 36.76433928)  21013960200      STROKE
# 4  POINT (-83.61861461 36.71356868)  21013960300      STROKE

# %%
#pivot categories column

health_ken_2019_clean_1 = health_ken_2019_clean.pivot_table(index='Category',observed=False)
health_ken_2019_clean_1.shape
health_ken_2019_clean_1.head(3)
# Out:
# (4, 6)
#                          CountyFIPS  Data_Value    LocationID  \
# Category
# Health Outcomes        21110.238698   19.059803  2.111065e+10
# Health Risk Behaviors  21110.238698   24.931133  2.111065e+10
# Health Status          21110.238698   19.579325  2.111065e+10
#
#                        TotalPopulation  Year          index
# Category
# Health Outcomes             3923.44123  2019  824579.768460
# Health Risk Behaviors       3923.44123  2019  827724.357444
# Health Status               3923.44123  2019  827265.377637

# %% [markdown]
# # Air Quality Data: Sulfur

# %%
#read data
so2 = pd.read_csv("daily_42401_2019_SO2.csv")
so2_ken = so2[so2["State Name"] == "Kentucky"]

#print the length of data
print("Length of original data: " + str(len(so2.index)))
print("Length of Kentucky data: " + str(len(so2_ken.index)))
print("Number of unique county in sulfur data: " + str(so2_ken["County Name"].nunique()))
pd.DataFrame(so2_ken["County Name"].value_counts())
# Out:
# Length of original data: 336542
# Length of Kentucky data: 8845
# Number of unique county in sulfur data: 10
#            County Name
# Jefferson         2179
# Henderson          848
# Boyd               730
# Edmonson           730
# Fayette            730
# Jessamine          730
# Campbell           728
# Daviess            726
# Greenup            724
# McCracken          720

# %%
so2_ken.head()
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC  Latitude  \
# 97694          21           19        17           42401    1  38.45934
# 97695          21           19        17           42401    1  38.45934
# 97696          21           19        17           42401    1  38.45934
# 97697          21           19        17           42401    1  38.45934
# 97698          21           19        17           42401    1  38.45934
#
#        Longitude  Datum  Parameter Name Sample Duration  ...  AQI Method Code  \
# 97694  -82.64041  WGS84  Sulfur dioxide          1 HOUR  ...  0.0       100.0
# 97695  -82.64041  WGS84  Sulfur dioxide          1 HOUR  ...  0.0       100.0
# 97696  -82.64041  WGS84  Sulfur dioxide          1 HOUR  ...  0.0       100.0
# 97697  -82.64041  WGS84  Sulfur dioxide          1 HOUR  ...  0.0       100.0
# 97698  -82.64041  WGS84  Sulfur dioxide          1 HOUR  ...  0.0       100.0
#
#                                    Method Name          Local Site Name  \
# 97694  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  ASHLAND PRIMARY (FIVCO)
# 97695  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  ASHLAND PRIMARY (FIVCO)
# 97696  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  ASHLAND PRIMARY (FIVCO)
# 97697  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  ASHLAND PRIMARY (FIVCO)
# 97698  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  ASHLAND PRIMARY (FIVCO)
#
#                                          Address  State Name  County Name  \
# 97694  FIVCO HEALTH DEPARTMENT, 2924 HOLT STREET    Kentucky         Boyd
# 97695  FIVCO HEALTH DEPARTMENT, 2924 HOLT STREET    Kentucky         Boyd
# 97696  FIVCO HEALTH DEPARTMENT, 2924 HOLT STREET    Kentucky         Boyd
# 97697  FIVCO HEALTH DEPARTMENT, 2924 HOLT STREET    Kentucky         Boyd
# 97698  FIVCO HEALTH DEPARTMENT, 2924 HOLT STREET    Kentucky         Boyd
#
#        City Name                     CBSA Name  Date of Last Change
# 97694    Ashland  Huntington-Ashland, WV-KY-OH           2021-11-01
# 97695    Ashland  Huntington-Ashland, WV-KY-OH           2021-11-01
# 97696    Ashland  Huntington-Ashland, WV-KY-OH           2021-11-01
# 97697    Ashland  Huntington-Ashland, WV-KY-OH           2021-11-01
# 97698    Ashland  Huntington-Ashland, WV-KY-OH           2021-11-01
#
# [5 rows x 29 columns]

# %%
health_county_names = list(pd.unique(health_ken_2019.CountyName))
so2_county_names = list(pd.unique(so2_ken["County Name"]))

merge_counts = [so2_names for so2_names in so2_county_names if so2_names in so2_county_names]

print("Counties in SO2: " + str(len(so2_county_names)))
print("Counties in tract: " + str(len(health_county_names)))
print("Counties we can merge on: " + str(len(merge_counts)))
# Out:
# Counties in SO2: 10
# Counties in tract: 120
# Counties we can merge on: 10

# %%
air_ken.head()
# Out:
#    index     State    County  Year  Days with AQI  Good Days  Moderate Days  \
# 0    326  Kentucky      Bell  2019            263        243             20
# 1    327  Kentucky     Boone  2019            239        222             17
# 2    328  Kentucky      Boyd  2019            365        313             52
# 3    329  Kentucky   Bullitt  2019            243        214             29
# 4    330  Kentucky  Campbell  2019            362        298             63
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    1               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0       77                   49          39        0
# 1               0       80                   49          39        0
# 2               0       74                   53          39        0
# 3               0       93                   51          41        0
# 4               0      108                   56          40        0
#
#    Days NO2  Days Ozone  Days PM2.5  Days PM10
# 0         0         234          29          0
# 1         0         239           0          0
# 2        11         192         160          2
# 3         0         243           0          0
# 4        21         189         152          0

# %%
## Reworking airq data:

# Aggregating by mean, reshaping & renaming
#agg_air = pd.DataFrame(air_ken.groupby(["County", "Defining Parameter"])["AQI"].mean().reset_index())
#agg_air_reshape = pd.pivot(agg_air[['County', 'Defining Parameter', 'AQI']],
#         index= 'County',
#         columns= 'Defining Parameter',
#         values = ['AQI']).reset_index()
#agg_air_reshape.columns = ['county_name', 'CO', "NO2", "ozone", "PM10", "PM2"]

# %%
## Reworking health data

# create function to find unique measure IDs for each category
def unique_measures(df, category):
  df_sub = df[["Category", "Measure", "MeasureId"]]
  focus_category = df_sub[df_sub["Category"] == category]
  return focus_category.MeasureId.unique()

# %%
## Reworking health data

## drop columns that we are not gonna use

# print the unique measures for reference and use in the focus_measures function 
# see codebook for full measure descriptions

unique_measures(health_ken_2019_clean, category = "Health Outcomes")
# we're interested in current asthma (CASTHMA), Chronic obstructive pulmonary disease among adults aged >=18 years' (COPD)
# Cancer (excluding skin cancer) among adults aged >=18 years (CANCER) and Depression among adults aged >=18 years (DEPRESSION)

unique_measures(health_ken_2019_clean, category = "Prevention")
# we're interested in Visits to doctor for routine checkup within the past year among adults aged (CHECKUP),
# Current lack of health insurance among adults aged 18-64 years (ACCESS2), and Taking medicine for high blood pressure control among 
# adults aged >=18 years with high blood pressure' (BPMED)

unique_measures(health_ken_2019_clean, category = "Health Risk Behaviors")
# we're interested in Current smoking among adults aged >=18 years (CSMOKING) and 
# No leisure-time physical activity among adults aged >=18 years (LPA)

unique_measures(health_ken_2019_clean, category = "Health Status")
# we're interested in Physical health not good for >=14 days among adults aged >=18 years (PHLTH),
# Mental health not good for >=14 days among adults aged >=18 years (MHLTH)
# Fair or poor self-rated health status among adults aged >=18 years' (GHLTH)
# Out:
# array(['STROKE', 'DEPRESSION', 'ARTHRITIS', 'CASTHMA', 'HIGHCHOL', 'CHD',
#        'OBESITY', 'CANCER', 'BPHIGH', 'DIABETES', 'KIDNEY', 'COPD'],
#       dtype=object)
# array(['CHOLSCREEN', 'BPMED', 'ACCESS2', 'CHECKUP'], dtype=object)
# array(['LPA', 'BINGE', 'CSMOKING'], dtype=object)
# array(['PHLTH', 'MHLTH', 'GHLTH'], dtype=object)

# %%
# create a function to subset to focuse measures for each category

def focus_measures(df, category, measures):
  focus_category = df[df['Category'].isin(category)]
  focus_measures = measures
  focus_category_measures = focus_category[focus_category["MeasureId"].isin(focus_measures)]
  return focus_category_measures

# %%
# create df subset to our focus measures 
all_categories = ["Health Outcomes", "Prevention", "Health Risk Behaviors", "Health Status"]
all_focus_measures = ["CANCER", 'COPD', 'CASTHMA', "DEPRESSION", "CHECKUP", 'ACCESS2', 'BPMED',"CSMOKING", 'LPA',"PHLTH", 'MHLTH','GHLTH']

health_ken_2019_clean.shape
health_ken_2019_fm = focus_measures(health_ken_2019_clean, category = all_categories, measures = all_focus_measures)
health_ken_2019_fm.shape
# Out:
# (24332, 13)
# (13272, 13)

# %%
#%store health_ken_2019_fm

# %%
# %store air_data
# %store air_ken
# %store air_ken_2019
# %store health_county_names
# %store health_data
# %store health_ken
# %store health_ken_2019
# %store health_ken_2019_clean
# %store health_ken_2019_fm
# %store so2
# %store so2_county_names
# %store so2_ken
# Out:
# Stored 'air_data' (DataFrame)
# Stored 'air_ken' (DataFrame)
# Stored 'air_ken_2019' (DataFrame)
# Stored 'health_county_names' (list)
# Stored 'health_data' (DataFrame)
# Stored 'health_ken' (DataFrame)
# Stored 'health_ken_2019' (DataFrame)
# Stored 'health_ken_2019_clean' (DataFrame)
# Stored 'health_ken_2019_fm' (DataFrame)
# Stored 'so2' (DataFrame)
# Stored 'so2_county_names' (list)
# Stored 'so2_ken' (DataFrame)
